# %%
# copied from https://github.com/karpathy/nanochat/blob/master/nanochat/tokenizer.py
SPLIT_PATTERN = r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,2}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+"""

# %%
import rust_tokenizer

# %%
play = rust_tokenizer.Play()

# %%
play.hello("Ernie")
# Out:
# 'hello Ernie'

# %%
play.get_type("Ernie")
# Out:
# "<class 'str'>"

# %%
play.get_type([1,2,3])
# Out:
# "<class 'list'>"

# %%
play.get_type(iter([1,2,3]))
# Out:
# "<class 'list_iterator'>"

# %%
play.concat_from_iterator(["the", "cat", "flew"])
# Out:
# 'thecatflew'

# %%
play.concat_from_iterator(123) # expect error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 play.concat_from_iterator(123) # expect error
#
# TypeError: 'int' object is not iterable

# %%
play.fancy_concat_from_iterator(["the", "cat", "flew"])
# Out:
# 'thecatflew'

# %%
play.find_matches(SPLIT_PATTERN, "They went to buy 1234 candies.")
# Out:
# ['They', ' went', ' to', ' buy', ' ', '12', '34', ' candies', '.']

# %%
tokenizer = rust_tokenizer.Tokenizer(debug_print = True)

# %%
tokenizer.train_from_iterator(
    iterator = ['the cat ate my soup cat', 'bats are the no fun cat', 'hello everyone the cat'],
    vocab_size = 300,
    buffer_size = 2,
    pattern = SPLIT_PATTERN
    )
# Out:
# bottom of loop, 'local' counts map: {" the": 1, " no": 1, " my": 1, "the": 1, "bats": 1, " soup": 1, " are": 1, " fun": 1, " cat": 3, " ate": 1}
# bottom of loop, length of 'global' counts map: 10
#
# bottom of loop, 'local' counts map: {"hello": 1, " everyone": 1, " cat": 1, " the": 1}
# bottom of loop, length of 'global' counts map: 12
#
# Done iterating
# counts map: {" everyone": 1, "hello": 1, "bats": 1, " are": 1, " my": 1, " fun": 1, " no": 1, " ate": 1, " the": 2, "the": 1, " soup": 1, " cat": 4}
# words: [[32, 101, 118, 101, 114, 121, 111, 110, 101], [104, 101, 108, 108, 111], [98, 97, 116, 115], [32, 97, 114, 101], [32, 109, 121], [32, 102, 117, 110], [32, 110, 111], [32, 97, 116, 101], [32, 116, 104, 101], [116, 104, 101], [32, 115, 111, 117, 112], [32, 99, 97, 116]]
# cvec: [1, 1, 1, 1, 1, 1, 1, 1, 2, 1, 1, 4]
